# %%
import pickle
import pandas as pd

# %%
with open("books.pkl", "rb") as file:
    books = pickle.loads(file.read())

# %%
x = pd.DataFrame().from_dict(books)

# %%
x.head()
# Out:
#    itemid     vendorid  available           code drmid  instock  \
# 0   58054  20160106626       True  9780062271174     1        1
# 1   24301  20160106626       True  9780373210312   NaN        1
# 2   58048  20160106626       True  9780062268181     1        1
# 3  297314  20160106626       True  9781488053733     1        1
# 4  299057  20160106626       True  9781488053894     1        1
#
#                                itemimage  listprice  mf_status mfgpartno  ...  \
# 0       [/covers/9780062271174/y404.jpg]       3.99          4        EB  ...
# 1  [/hqna/covers/9780373210312/y404.jpg]       9.99          4        TP  ...
# 2       [/covers/9780062268181/y404.jpg]      11.99          4        EB  ...
# 3  [/hqna/covers/9781488053733/y404.jpg]       3.99          4        EB  ...
# 4  [/hqna/covers/9781488053894/y404.jpg]       3.99          4        EB  ...
#
#           brandname      sub_isbn_TP miniseriesid   miniseriesname  \
# ...

# %%
type(x["itemimage"].iloc[0])
# Out:
# list

# %%
x[x["itemimage"].apply(len) > 1]
# Out:
# Empty DataFrame
# Columns: [itemid, vendorid, available, code, drmid, instock, itemimage, listprice, mf_status, mfgpartno, podate, price, publicationdate, shortdesc, soldout, title, width, authorid, authorname, productseourl, sub_format_exist_PB, sub_format_exist_EB, sub_isbn_EB, sub_digitalexcerpt_EB, sub_format_exist_HC, sub_format_exist_TP, sub_format_exist_LP, sub_format_exist_AB, listprice_USD, price_USD, listprice_CAD, price_CAD, categoryid, categoryname, brandid, brandname, sub_isbn_TP, miniseriesid, miniseriesname, sub_isbn_PB, sub_isbn_AB, sub_isbn_HC, sub_isbn_LP, listprice_PTS, price_PTS]
# Index: []
#
# [0 rows x 45 columns]
